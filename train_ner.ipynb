# %%
import pandas as pd

products = pd.read_csv("amazon_products.csv")

# %%
products.head()
# Out:
#                                                title      brand        asin
# 0  FLT&reg; Laptop AC Adapter/Power Supply/Charge...        FLT  6666666038
# 1  uxcell Flexible Neck Black Three Blade Compute...     uxcell  7884139057
# 2  IKEA - UPPT&Auml;CKA Backpack, dark gray, yell...       IKEA  9178910897
# 3              Princeton Eo2010 21" Monitor (Pc/Mac)  Princeton  B00001MXZ7
# 4                         ViewSonic E790 19" Monitor  ViewSonic  B00004TS2P

# %%
UNIQUE_BRANDS = products["brand"].unique()
len(UNIQUE_BRANDS)
# Out:
# 1301

# %% [markdown]
# ## Split data
#
# Split data info test and trainval subsets

# %%
import random

random.seed(2022)
random.shuffle(UNIQUE_BRANDS)


TEST_SPLIT_FRAC = 0.15
TEST_SPLIT = int(TEST_SPLIT_FRAC * len(UNIQUE_BRANDS))

TEST_DATA_BRANDS = UNIQUE_BRANDS[:TEST_SPLIT]
TRAINVAL_DATA_BRANDS = UNIQUE_BRANDS[TEST_SPLIT:]

test_dataframe = products[products["brand"].isin(TEST_DATA_BRANDS)]
trainval_dataframe = products[products["brand"].isin(TRAINVAL_DATA_BRANDS)]

# %% [markdown]
# ## Build dataset
#
# - Clean the data
# - Transform data for model training

# %%
import re

def transform(text: str, brand: str):
    text = re.sub('&.*;', '', text)
    start_index = text.find(brand)
    if start_index == -1:
        print(f"[ERROR] No brand `{brand}` in `{text}`")
        return None
    end_index = len(brand)
    return (text, {"entities" : [(start_index, end_index, "BRAND")]})

def build_data_from_dataframe(dataframe):
    data = []
    for row in dataframe.itertuples(index=False):
        sample = transform(row.title, row.brand)
        if sample is None:
            continue
        data.append(sample)
    return data

TRAIN_DATA = build_data_from_dataframe(trainval_dataframe)

TEST_DATA = build_data_from_dataframe(test_dataframe)
# Out:
# [ERROR] No brand `Game Time` in ` 3 Color Backlit LED Illuminated Professional USB Gaming Keyboard (JW-200)`

# %%
TRAIN_DATA[:5]
# Out:
# [('FLT Laptop AC Adapter/Power Supply/Charger+US Power Cord for Toshiba Satellite',
#   {'entities': [(0, 3, 'BRAND')]}),
#  ('uxcell Flexible Neck Black Three Blade Computer USB Desk Fan',
#   {'entities': [(0, 6, 'BRAND')]}),
#  ('Princeton Eo2010 21" Monitor (Pc/Mac)', {'entities': [(0, 9, 'BRAND')]}),
#  ('ViewSonic E790 19" Monitor', {'entities': [(0, 9, 'BRAND')]}),
#  ('ViewSonic E-790B 19 Monitor', {'entities': [(0, 9, 'BRAND')]})]

# %%
import spacy

spacy.__version__
# Out:
# '2.3.7'

# %%
# Import requirements
import random
from spacy.util import minibatch, compounding
from spacy.util import get_words_and_spaces
from spacy.tokens import Doc, DocBin
from pathlib import Path

# CREATE BLANK MODEL
pretrained_model = None # "en_core_web_md"
if pretrained_model:
    nlp = spacy.load(pretrained_model)
    print("Loaded model: ", pretrained_model)
else:
    nlp = spacy.blank("en")
    print("Create blank 'en' model")

if 'ner' not in nlp.pipe_names:
    ner = nlp.create_pipe("ner")
    nlp.add_pipe(ner, last=True)
else:
    ner = nlp.get_pipe("ner")

# ADD LABEL
ner.add_label("BRAND")

# TRAINING THE MODEL
# Disable pipeline components which we don't need to change
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
with nlp.disable_pipes(*other_pipes):

    # reset and initialize the weights randomly – but only if we're training new blank model 
    if pretrained_model is None:
        nlp.begin_training()
    # Training for 30 iterations
    for iteration in range(200):
        # shuufling examples  before every iteration
        random.shuffle(TRAIN_DATA)
        losses = {}
        batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
        # for text, annotations in TRAIN_DATA:
        for batch in batches:
            texts, annotations = zip(*batch)
            nlp.update(
                texts,
                annotations,
                drop=0.5,  # dropout - make it harder to memorise data
                losses=losses,
            )
        print(f"[{iteration}] Batch loss {losses}")
# Out:
# Create blank 'en' model
# [0] Batch loss {'ner': 1450.4714119942191}
# [1] Batch loss {'ner': 1549.3395661883408}
# [2] Batch loss {'ner': 1256.3288791306627}
# [3] Batch loss {'ner': 1198.7894069816498}
# [4] Batch loss {'ner': 871.8195317934872}
# [5] Batch loss {'ner': 718.0835352186884}
# [6] Batch loss {'ner': 718.012841829665}
# [7] Batch loss {'ner': 736.2810548618392}
# [8] Batch loss {'ner': 460.033027812419}
# [9] Batch loss {'ner': 517.558310427669}
# [10] Batch loss {'ner': 464.6186634904239}
# [11] Batch loss {'ner': 348.35220317545514}
# [12] Batch loss {'ner': 320.4880800608878}
# [13] Batch loss {'ner': 322.2307480936164}
# [14] Batch loss {'ner': 287.07962707856115}
# [15] Batch loss {'ner': 335.78631916897024}
# [16] Batch loss {'ner': 236.60022061812614}
# [17] Batch loss {'ner': 229.27335658112798}
# [18] Batch loss {'ner': 217.1399670161359}
# [19] Batch loss {'ner': 287.1779490305446}
# [20] Batch loss {'ner': 191.11962758012277}
# [21] Batch loss {'ner': 143.51020512510166}
# [22] Batch loss {'ner': 213.7745279875509}
# [23] Batch loss {'ner': 233.5594613304401}
# [24] Batch loss {'ner': 164.33406185451065}
# [25] Batch loss {'ner': 169.9668659682096}
# [26] Batch loss {'ner': 198.60925707193277}
# [27] Batch loss {'ner': 163.9238924091412}
# [28] Batch loss {'ner': 172.85624118598545}
# [29] Batch loss {'ner': 156.96445398190303}
# [30] Batch loss {'ner': 96.74142769248489}
# [31] Batch loss {'ner': 147.02821060680262}
# [32] Batch loss {'ner': 134.51916382543925}
# [33] Batch loss {'ner': 145.70832587190858}
# [34] Batch loss {'ner': 222.45302703197157}
# [35] Batch loss {'ner': 247.84526560676372}
# [36] Batch loss {'ner': 185.7860383788182}
# [37] Batch loss {'ner': 111.77242364336526}
# [38] Batch loss {'ner': 172.92370092016492}
# [39] Batch loss {'ner': 202.36434131361784}
# [40] Batch loss {'ner': 159.20284569188058}
# [41] Batch loss {'ner': 162.77154452378122}
# [42] Batch loss {'ner': 141.13453974274506}
# [43] Batch loss {'ner': 127.78241612378027}
# [44] Batch loss {'ner': 143.95147082921355}
# [45] Batch loss {'ner': 96.6223622456938}
# [46] Batch loss {'ner': 128.33390184924363}
# [47] Batch loss {'ner': 119.4406983332787}
# [48] Batch loss {'ner': 87.9008006093287}
# [49] Batch loss {'ner': 91.29337743066247}
# [50] Batch loss {'ner': 81.41397214494455}
# [51] Batch loss {'ner': 87.8297867455263}
# [52] Batch loss {'ner': 108.56420432828357}
# [53] Batch loss {'ner': 85.57032735650309}
# [54] Batch loss {'ner': 96.17789069091344}
# [55] Batch loss {'ner': 118.22807166597762}
# [56] Batch loss {'ner': 95.44790921054651}
# [57] Batch loss {'ner': 76.88462711362729}
# [58] Batch loss {'ner': 94.42850901996547}
# [59] Batch loss {'ner': 76.09789327718053}
# [60] Batch loss {'ner': 97.89944639561453}
# [61] Batch loss {'ner': 77.44554565448942}
# [62] Batch loss {'ner': 76.73110382870132}
# [63] Batch loss {'ner': 95.48306734142204}
# [64] Batch loss {'ner': 113.14148700243933}
# [65] Batch loss {'ner': 108.61842662034238}
# [66] Batch loss {'ner': 161.17543415493316}
# [67] Batch loss {'ner': 105.40854246066873}
# [68] Batch loss {'ner': 78.03591995183643}
# [69] Batch loss {'ner': 56.54148316500475}
# [70] Batch loss {'ner': 82.4265236862825}
# [71] Batch loss {'ner': 89.45829469870706}
# [72] Batch loss {'ner': 90.8497125410236}
# [73] Batch loss {'ner': 129.72900342664948}
# [74] Batch loss {'ner': 49.53767172693204}
# [75] Batch loss {'ner': 68.44426903137122}
# [76] Batch loss {'ner': 77.91305721238245}
# [77] Batch loss {'ner': 86.49340996351694}
# [78] Batch loss {'ner': 52.30021462415877}
# [79] Batch loss {'ner': 86.77770549718781}
# [80] Batch loss {'ner': 89.68235415221126}
# [81] Batch loss {'ner': 88.27816750990337}
# [82] Batch loss {'ner': 85.48831874409159}
# [83] Batch loss {'ner': 57.19725139711583}
# [84] Batch loss {'ner': 64.04447760815955}
# [85] Batch loss {'ner': 75.7766751221445}
# [86] Batch loss {'ner': 89.21987898954771}
# [87] Batch loss {'ner': 90.73846020753969}
# [88] Batch loss {'ner': 83.85688194885633}
# [89] Batch loss {'ner': 50.83944593166989}
# [90] Batch loss {'ner': 106.52647575721376}
# [91] Batch loss {'ner': 97.11049763590835}
# [92] Batch loss {'ner': 60.64772991845293}
# [93] Batch loss {'ner': 58.474845805021005}
# [94] Batch loss {'ner': 96.429509168694}
# [95] Batch loss {'ner': 87.60124328540695}
# [96] Batch loss {'ner': 81.60173407290138}
# [97] Batch loss {'ner': 49.06006414448175}
# [98] Batch loss {'ner': 52.965809771428646}
# [99] Batch loss {'ner': 77.91732736527429}
# [100] Batch loss {'ner': 47.69784453482964}
# [101] Batch loss {'ner': 39.5457902545746}
# [102] Batch loss {'ner': 58.16260397676283}
# [103] Batch loss {'ner': 68.93638273615984}
# [104] Batch loss {'ner': 73.56524796505246}
# [105] Batch loss {'ner': 94.75537133063891}
# [106] Batch loss {'ner': 53.170371957350326}
# [107] Batch loss {'ner': 96.98383103868746}
# [108] Batch loss {'ner': 107.01602230462431}
# [109] Batch loss {'ner': 72.34351808156394}
# [110] Batch loss {'ner': 71.48967228691026}
# [111] Batch loss {'ner': 95.94102774080054}
# [112] Batch loss {'ner': 80.05184057087615}
# [113] Batch loss {'ner': 57.9196374010119}
# [114] Batch loss {'ner': 67.10501277742154}
# [115] Batch loss {'ner': 68.79095368258821}
# [116] Batch loss {'ner': 88.96962908958942}
# [117] Batch loss {'ner': 43.22747935894213}
# [118] Batch loss {'ner': 65.03092317250427}
# [119] Batch loss {'ner': 53.75081997721174}
# [120] Batch loss {'ner': 35.70090142963026}
# [121] Batch loss {'ner': 45.66555635985542}
# [122] Batch loss {'ner': 65.5016846909786}
# [123] Batch loss {'ner': 45.136343419403914}
# [124] Batch loss {'ner': 89.34168846108544}
# [125] Batch loss {'ner': 46.63123498938973}
# [126] Batch loss {'ner': 61.9303103860833}
# [127] Batch loss {'ner': 68.69884432530498}
# [128] Batch loss {'ner': 54.44687409833149}
# [129] Batch loss {'ner': 43.24508424820359}
# [130] Batch loss {'ner': 61.7459672725614}
# [131] Batch loss {'ner': 49.79661651478582}
# [132] Batch loss {'ner': 40.799187639442195}
# [133] Batch loss {'ner': 43.42274951687428}
# [134] Batch loss {'ner': 72.48052088283663}
# [135] Batch loss {'ner': 55.02856716096853}
# [136] Batch loss {'ner': 92.07235204529483}
# [137] Batch loss {'ner': 61.90439360107921}
# [138] Batch loss {'ner': 68.69817977592294}
# [139] Batch loss {'ner': 37.759630068638444}
# [140] Batch loss {'ner': 65.68351880325285}
# [141] Batch loss {'ner': 77.90392323837001}
# [142] Batch loss {'ner': 50.744893517926}
# [143] Batch loss {'ner': 55.64832691454395}
# [144] Batch loss {'ner': 46.93974882883571}
# [145] Batch loss {'ner': 33.26672451671751}
# [146] Batch loss {'ner': 26.988143863395518}
# [147] Batch loss {'ner': 71.65035103773282}
# [148] Batch loss {'ner': 42.60215937797948}
# [149] Batch loss {'ner': 39.91109424473203}
# [150] Batch loss {'ner': 51.64884593654625}
# [151] Batch loss {'ner': 83.19108849245671}
# [152] Batch loss {'ner': 26.29056180467251}
# [153] Batch loss {'ner': 60.0301570713435}
# [154] Batch loss {'ner': 68.10229624862768}
# [155] Batch loss {'ner': 72.32186805993297}
# [156] Batch loss {'ner': 50.56141350872827}
# [157] Batch loss {'ner': 76.61660084259522}
# [158] Batch loss {'ner': 49.93979688905166}
# [159] Batch loss {'ner': 87.61202369947567}
# [160] Batch loss {'ner': 74.18326320348393}
# [161] Batch loss {'ner': 87.09921538532059}
# [162] Batch loss {'ner': 51.30544894040677}
# [163] Batch loss {'ner': 79.53845286236361}
# [164] Batch loss {'ner': 61.240559603908295}
# [165] Batch loss {'ner': 46.046002248792576}
# [166] Batch loss {'ner': 83.33037904397654}
# [167] Batch loss {'ner': 51.59126115163545}
# [168] Batch loss {'ner': 44.622938688634804}
# [169] Batch loss {'ner': 54.58211524209611}
# [170] Batch loss {'ner': 56.36324473046098}
# [171] Batch loss {'ner': 35.5372885036442}
# [172] Batch loss {'ner': 38.28115028484124}
# [173] Batch loss {'ner': 55.52287548093964}
# [174] Batch loss {'ner': 47.431075126762835}
# [175] Batch loss {'ner': 54.61804882442524}
# [176] Batch loss {'ner': 36.05655230839887}
# [177] Batch loss {'ner': 60.508047112416435}
# [178] Batch loss {'ner': 27.06642960156978}
# [179] Batch loss {'ner': 33.320166371929616}
# [180] Batch loss {'ner': 21.23386595967652}
# [181] Batch loss {'ner': 47.08086841888605}
# [182] Batch loss {'ner': 58.18512074342594}
# [183] Batch loss {'ner': 64.60094492649739}
# [184] Batch loss {'ner': 32.55066849466307}
# [185] Batch loss {'ner': 35.12052239157308}
# [186] Batch loss {'ner': 48.812852971849885}
# [187] Batch loss {'ner': 35.16247395599031}
# [188] Batch loss {'ner': 53.71009331694187}
# [189] Batch loss {'ner': 27.807247448997394}
# [190] Batch loss {'ner': 25.229130030348767}
# [191] Batch loss {'ner': 44.13636676645166}
# [192] Batch loss {'ner': 42.97961112343909}
# [193] Batch loss {'ner': 40.99253583278108}
# [194] Batch loss {'ner': 27.74515455437336}
# [195] Batch loss {'ner': 41.559706772779904}
# [196] Batch loss {'ner': 49.435353305714116}
# [197] Batch loss {'ner': 33.03597746282668}
# [198] Batch loss {'ner': 50.477883137770014}
# [199] Batch loss {'ner': 42.79893821111945}

# %%
from pathlib import Path
output_dir = Path("pretrained_models/en_conrad_ner")
if not output_dir.exists():
    output_dir.mkdir(parents=True, exist_ok=True)
nlp.to_disk(output_dir)
print("Saving model to", output_dir)
# Out:
# Saving model to pretrained_models/en_conrad_ner

# %%
print("Loading model from", output_dir)
nlp2 = spacy.load(output_dir)
accurate_predictions = 0
for text, annotations in TEST_DATA:
    doc = nlp2(text)
    predictions = [(ent.text, ent.label_) for ent in doc.ents]
    gold = [(text[start:end], label) for start, end, label in annotations["entities"]]

    if set(predictions) == set(gold):
        print("Correct:", predictions)
        accurate_predictions += 1
    else:
        print('Wrong: Prediction', predictions, " -- Gold", gold)

print("Accuracy", accurate_predictions/len(TEST_DATA))
# Out:
# Loading model from pretrained_models/en_conrad_ner
# Correct: [('IKEA', 'BRAND')]
# Correct: [('Labtec', 'BRAND')]
# Correct: [('APC', 'BRAND')]
# Wrong: Prediction []  -- Gold [('IBM', 'BRAND')]
# Wrong: Prediction []  -- Gold [('D-Link', 'BRAND')]
# Correct: [('NETGEAR', 'BRAND')]
# Correct: [('Rikaline', 'BRAND')]
# Correct: [('Alpine', 'BRAND')]
# Correct: [('Net Nanny', 'BRAND')]
# Correct: [('Pocketec', 'BRAND')]
# Correct: [('Targus', 'BRAND')]
# Correct: [('3Com', 'BRAND')]
# Wrong: Prediction [('Targus Mobile', 'BRAND')]  -- Gold [('Targus', 'BRAND')]
# Correct: [('Samsonite', 'BRAND')]
# Wrong: Prediction [('LAKELAND', 'BRAND')]  -- Gold [('', 'BRAND')]
# Correct: [('Nokia', 'BRAND')]
# Correct: [('Maxent', 'BRAND')]
# Correct: [('DSI', 'BRAND')]
# Correct: [('ByteRunner', 'BRAND')]
# Correct: [('APACER', 'BRAND')]
# Correct: [('Samsonite', 'BRAND')]
# Correct: [('TrackItBack', 'BRAND')]
# Correct: [('iLuv', 'BRAND')]
# Wrong: Prediction [('Nuo', 'BRAND')]  -- Gold [('Chloe', 'BRAND')]
# Correct: [('BandRich', 'BRAND')]
# Wrong: Prediction [('Palm', 'BRAND')]  -- Gold [('', 'BRAND')]
# Correct: [('Maxent', 'BRAND')]
# Wrong: Prediction [('Moshi Celesta English', 'BRAND')]  -- Gold [('Moshi', 'BRAND')]
# Wrong: Prediction [('InclinePro Cooling', 'BRAND')]  -- Gold [('InclinePro', 'BRAND')]
# Correct: [('Quail', 'BRAND')]
# Wrong: Prediction [('NES42498', 'BRAND')]  -- Gold [('', 'BRAND')]
# Correct: [('Dynex', 'BRAND')]
# Correct: [('Connect-A-Desk', 'BRAND')]
# Correct: [('PPA', 'BRAND')]
# Correct: [('Audioengine', 'BRAND')]
# Correct: [('Scythe', 'BRAND')]
# Correct: [('Scythe', 'BRAND')]
# Correct: [('CaseCrown', 'BRAND')]
# Correct: [('SuperMediaStore', 'BRAND')]
# Correct: [('Scythe', 'BRAND')]
# Correct: [('Scythe', 'BRAND')]
# Wrong: Prediction [('Sierra', 'BRAND')]  -- Gold [('Sierra Wireless', 'BRAND')]
# Correct: [('EZDigiMagic', 'BRAND')]
# Correct: [('Heys', 'BRAND')]
# Correct: [('CaseCrown', 'BRAND')]
# Correct: [('CaseCrown', 'BRAND')]
# Wrong: Prediction [('VEHO', 'BRAND')]  -- Gold [('VEHO UK', 'BRAND')]
# Wrong: Prediction [('David', 'BRAND')]  -- Gold [('David Clark', 'BRAND')]
# Correct: [('3Com', 'BRAND')]
# Correct: [('Bone', 'BRAND')]
# Wrong: Prediction [('Crucial', 'BRAND')]  -- Gold [('Crucial Technology', 'BRAND')]
# Correct: [('Kroo', 'BRAND')]
# Correct: [('Samsonite', 'BRAND')]
# Correct: [('Lilliput', 'BRAND')]
# Wrong: Prediction [('Yate', 'BRAND')]  -- Gold [('Yate Loon', 'BRAND')]
# Correct: [('Kikkerland', 'BRAND')]
# Wrong: Prediction []  -- Gold [('L-com', 'BRAND')]
# Correct: [('Tuniq', 'BRAND')]
# Correct: [('Mushkin', 'BRAND')]
# Wrong: Prediction [('Palo', 'BRAND')]  -- Gold [('Palo Alto Software', 'BRAND')]
# Wrong: Prediction [('Turtle', 'BRAND')]  -- Gold [('Turtle Beach', 'BRAND')]
# Correct: [('CaseCrown', 'BRAND')]
# Correct: [('CaseCrown', 'BRAND')]
# Correct: [('Medialink', 'BRAND')]
# Correct: [('Matias', 'BRAND')]
# Correct: [('TekRam', 'BRAND')]
# Correct: [('Kobo', 'BRAND')]
# Correct: [('Scythe', 'BRAND')]
# Correct: [('Pelican', 'BRAND')]
# Correct: [('Gefen', 'BRAND')]
# Correct: [('CaseCrown', 'BRAND')]
# Correct: [('JAVOedge', 'BRAND')]
# Wrong: Prediction [('Alien', 'BRAND')]  -- Gold [('Alien Skin', 'BRAND')]
# Correct: [('BulletTrain', 'BRAND')]
# Wrong: Prediction [('Swiss Gear Corporate Ballistic', 'BRAND')]  -- Gold [('Swiss Gear', 'BRAND')]
# Correct: [('Homedics', 'BRAND')]
# Correct: [('MountMe', 'BRAND')]
# Wrong: Prediction [('Waterproof', 'BRAND')]  -- Gold [('', 'BRAND')]
# Wrong: Prediction []  -- Gold [('IBM', 'BRAND')]
# Correct: [('MoKo', 'BRAND')]
# Correct: [('Cyborg', 'BRAND')]
# Wrong: Prediction [('Generiks TM', 'BRAND')]  -- Gold [('Generiks', 'BRAND')]
# Wrong: Prediction []  -- Gold [('', 'BRAND')]
# Wrong: Prediction [('Targus Truss', 'BRAND')]  -- Gold [('Targus', 'BRAND')]
# Wrong: Prediction [('DODOcase for', 'BRAND')]  -- Gold [('DODOcase', 'BRAND')]
# Correct: [('Sonicwall', 'BRAND')]
# Wrong: Prediction [('Grass', 'BRAND')]  -- Gold [('Grass Valley', 'BRAND')]
# Wrong: Prediction [('DODOcase for', 'BRAND')]  -- Gold [('DODOcase', 'BRAND')]
# Correct: [('Sonicwall', 'BRAND')]
# Wrong: Prediction [('Coby Kyros', 'BRAND')]  -- Gold [('Coby', 'BRAND')]
# Correct: [('ePillow', 'BRAND')]
# Correct: [('Flashmanusb', 'BRAND')]
# Correct: [('Areca', 'BRAND')]
# Wrong: Prediction []  -- Gold [('IBM', 'BRAND')]
# Correct: [('Flashmanusb', 'BRAND')]
# Correct: [('Rapoo', 'BRAND')]
# Correct: [('Rapoo', 'BRAND')]
# Correct: [('Quirky', 'BRAND')]
# Wrong: Prediction [('StarTech.com', 'BRAND')]  -- Gold [('StarTech', 'BRAND')]
# Wrong: Prediction []  -- Gold [('D-Link', 'BRAND')]
# Wrong: Prediction [('1 World', 'BRAND')]  -- Gold [('1 World Sarongs', 'BRAND')]
# Correct: [('Sonicwall', 'BRAND')]
# Correct: [('Everydaysource', 'BRAND')]
# Correct: [('Everydaysource', 'BRAND')]
# Correct: [('Everydaysource', 'BRAND')]
# Correct: [('TOOGOO', 'BRAND')]
# Correct: [('Everydaysource', 'BRAND')]
# Correct: [('Everydaysource', 'BRAND')]
# Correct: [('SuperSSpeed', 'BRAND')]
# Correct: [('CaseCrown', 'BRAND')]
# Correct: [('Everydaysource', 'BRAND')]
# Wrong: Prediction []  -- Gold [('D-Link', 'BRAND')]
# Correct: [('Everydaysource', 'BRAND')]
# Correct: [('BW', 'BRAND')]
# Correct: [('Imation', 'BRAND')]
# Correct: [('Kobo', 'BRAND')]
# Correct: [('Netatmo', 'BRAND')]
# Wrong: Prediction [('Wave', 'BRAND')]  -- Gold [('Wave WiFi', 'BRAND')]
# Correct: [('Rapoo', 'BRAND')]
# Correct: [('Rapoo', 'BRAND')]
# Wrong: Prediction []  -- Gold [('IBM', 'BRAND')]
# Correct: [('Drobo', 'BRAND')]
# Correct: [('Schatzii', 'BRAND')]
# Correct: [('Mohu', 'BRAND')]
# Correct: [('Tanboo', 'BRAND')]
# Wrong: Prediction []  -- Gold [('DODOcase', 'BRAND')]
# Correct: [('AURALiC', 'BRAND')]
# Wrong: Prediction []  -- Gold [("Dora the Explorer Let's Play Backpack", 'BRAND')]
# Correct: [('Ducky', 'BRAND')]
# Correct: [('Samsonite', 'BRAND')]
# Correct: [('NETGEAR', 'BRAND')]
# Wrong: Prediction [('Incipio Essentials', 'BRAND')]  -- Gold [('Incipio', 'BRAND')]
# Correct: [('Jawbone', 'BRAND')]
# Wrong: Prediction [('ARECA', 'BRAND')]  -- Gold [('', 'BRAND')]
# Correct: [('Targus', 'BRAND')]
# Correct: [('Ducky', 'BRAND')]
# Correct: [('A-jazz', 'BRAND')]
# Correct: [('Claybox', 'BRAND')]
# Correct: [('Claybox', 'BRAND')]
# Correct: [('Targus', 'BRAND')]
# Correct: [('CyberpowerPC', 'BRAND')]
# Correct: [('iWalk', 'BRAND')]
# Wrong: Prediction [('CE', 'BRAND')]  -- Gold [('CE Compass', 'BRAND')]
# Wrong: Prediction [('Betty', 'BRAND')]  -- Gold [('Betty Boop', 'BRAND')]
# Wrong: Prediction []  -- Gold [('D-Link', 'BRAND')]
# Wrong: Prediction []  -- Gold [('D-Link', 'BRAND')]
# Correct: [('NETGEAR', 'BRAND')]
# Correct: [('Anker', 'BRAND')]
# Correct: [('Targus', 'BRAND')]
# Correct: [('Targus', 'BRAND')]
# Correct: [('Targus', 'BRAND')]
# Correct: [('Bodu', 'BRAND')]
# Correct: [('MyDigitalSSD', 'BRAND')]
# Correct: [('Scythe', 'BRAND')]
# Wrong: Prediction [('Earth', 'BRAND')]  -- Gold [('Earth People Technology', 'BRAND')]
# Correct: [('NETGEAR', 'BRAND')]
# Correct: [('Incipio', 'BRAND')]
# Correct: [('SumacLife', 'BRAND')]
# Correct: [('GERBER', 'BRAND')]
# Correct: [('Rapoo', 'BRAND')]
# Wrong: Prediction [('J5', 'BRAND')]  -- Gold [('J5 Create', 'BRAND')]
# Wrong: Prediction [('GARMIN', 'BRAND')]  -- Gold [('', 'BRAND')]
# Wrong: Prediction []  -- Gold [('Kit', 'BRAND')]
# Correct: [('JVC', 'BRAND')]
# Correct: [('JVC', 'BRAND')]
# Correct: [('JVC', 'BRAND')]
# Correct: [('3CLeader', 'BRAND')]
# Correct: [('3CLeader', 'BRAND')]
# Correct: [('CaseCrown', 'BRAND')]
# Correct: [('CaseCrown', 'BRAND')]
# Correct: [('iHeartRaves', 'BRAND')]
# Correct: [('Datavideo', 'BRAND')]
# Wrong: Prediction []  -- Gold [('', 'BRAND')]
# Correct: [('Thermos', 'BRAND')]
# Correct: [('CyberpowerPC', 'BRAND')]
# Correct: [('CyberpowerPC', 'BRAND')]
# Wrong: Prediction []  -- Gold [('3CLeader', 'BRAND')]
# Wrong: Prediction []  -- Gold [('3CLeader', 'BRAND')]
# Correct: [('CyberpowerPC', 'BRAND')]
# Wrong: Prediction []  -- Gold [('3CLeader', 'BRAND')]
# Correct: [('3CLeader', 'BRAND')]
# Correct: [('HOTT', 'BRAND')]
# Correct: [('3CLeader', 'BRAND')]
# Correct: [('DuaFire', 'BRAND')]
# Wrong: Prediction []  -- Gold [('CY', 'BRAND')]
# Correct: [('Socket', 'BRAND')]
# Correct: [('KAYOND', 'BRAND')]
# Correct: [('KAYOND', 'BRAND')]
# Correct: [('Seibertron', 'BRAND')]
# Correct: [('Adafruit', 'BRAND')]
# Correct: [('Noctua', 'BRAND')]
# Correct: [('Noctua', 'BRAND')]
# Wrong: Prediction []  -- Gold [('D-Link', 'BRAND')]
# Correct: [('CyberpowerPC', 'BRAND')]
# Correct: [('CyberpowerPC', 'BRAND')]
# Correct: [('CyberpowerPC', 'BRAND')]
# Correct: [('CyberpowerPC', 'BRAND')]
# Correct: [('Kamo', 'BRAND')]
# Correct: [('Niceshop', 'BRAND')]
# Wrong: Prediction [('Vintage', 'BRAND')]  -- Gold [('', 'BRAND')]
# Correct: [('Monster Cable', 'BRAND')]
# Correct: [('BRYCO', 'BRAND')]
# Wrong: Prediction [('Port', 'BRAND')]  -- Gold [('Port Authority', 'BRAND')]
# Wrong: Prediction []  -- Gold [('', 'BRAND')]
# Correct: [('Icicle', 'BRAND')]
# Correct: [('Icicle', 'BRAND')]
# Correct: [('Staples', 'BRAND')]
# Correct: [('Gdstime', 'BRAND')]
# Correct: [('Mushkin', 'BRAND')]
# Correct: [('Adafruit', 'BRAND')]
# Correct: [('Adafruit', 'BRAND')]
# Correct: [('Bioworld', 'BRAND')]
# Correct: [('Ducky', 'BRAND')]
# Correct: [('Coollaboratory', 'BRAND')]
# Correct: [('Pelican', 'BRAND')]
# Wrong: Prediction [('Hamilton', 'BRAND')]  -- Gold [('Hamilton Beach', 'BRAND')]
# Correct: [('Adafruit', 'BRAND')]
# Correct: [('Adafruit', 'BRAND')]
# Wrong: Prediction [('DPI', 'BRAND')]  -- Gold [('DPI INc', 'BRAND')]
# Wrong: Prediction [('E-3lue', 'BRAND')]  -- Gold [('', 'BRAND')]
# Correct: [('LanLan', 'BRAND')]
# Wrong: Prediction [('Mactrem', 'BRAND')]  -- Gold [('', 'BRAND')]
# Correct: [('LanLan', 'BRAND')]
# Wrong: Prediction [('Outdoor', 'BRAND')]  -- Gold [('Outdoor Edge', 'BRAND')]
# Correct: [('Bheema', 'BRAND')]
# Correct: [('Delta', 'BRAND')]
# Wrong: Prediction [('Incipio Technologies', 'BRAND')]  -- Gold [('Incipio', 'BRAND')]
# Correct: [('DigiScan', 'BRAND')]
# Correct: [('ASUS', 'BRAND')]
# Correct: [('Hipstreet', 'BRAND')]
# Correct: [('Rapoo', 'BRAND')]
# Correct: [('SUPERTALENT', 'BRAND')]
# Correct: [('Ducky', 'BRAND')]
# Correct: [('Ducky', 'BRAND')]
# Correct: [('Ducky', 'BRAND')]
# Correct: [('Ducky', 'BRAND')]
# Wrong: Prediction [('Beon', 'BRAND')]  -- Gold [('Beon Global', 'BRAND')]
# Correct: [('MAIYUAN', 'BRAND')]
# Wrong: Prediction []  -- Gold [('CY', 'BRAND')]
# Wrong: Prediction []  -- Gold [('CY', 'BRAND')]
# Correct: [('Graco', 'BRAND')]
# Correct: [('CISNO', 'BRAND')]
# Correct: [('JanSport', 'BRAND')]
# Correct: [('VERY100', 'BRAND')]
# Correct: [('VERY100', 'BRAND')]
# Correct: [('VERY100', 'BRAND')]
# Correct: [('Specam', 'BRAND')]
# Correct: [('CyberpowerPC', 'BRAND')]
# Correct: [('CyberpowerPC', 'BRAND')]
# Wrong: Prediction []  -- Gold [('3CLeader', 'BRAND')]
# Correct: [('Uncommon', 'BRAND')]
# Correct: [('ASUS', 'BRAND')]
# Wrong: Prediction []  -- Gold [('Maxtor', 'BRAND')]
# Wrong: Prediction []  -- Gold [('3CLeader', 'BRAND')]
# Wrong: Prediction []  -- Gold [('3CLeader', 'BRAND')]
# Correct: [('Suily', 'BRAND')]
# Correct: [('Leathario', 'BRAND')]
# Correct: [('Nicole Lee', 'BRAND')]
# Correct: [('Doinshop', 'BRAND')]
# Correct: [('Ducky', 'BRAND')]
# Correct: [('LCDOLED', 'BRAND')]
# Correct: [('IBM', 'BRAND')]
# Correct: [('Burton', 'BRAND')]
# Correct: [('Adafruit', 'BRAND')]
# Correct: [('JanSport', 'BRAND')]
# Correct: [('Quirky', 'BRAND')]
# Correct: [('Foryee', 'BRAND')]
# Correct: [('Doinshop', 'BRAND')]
# Wrong: Prediction [('Thermal', 'BRAND')]  -- Gold [('Thermal Grizzly', 'BRAND')]
# Wrong: Prediction [('Thermal', 'BRAND')]  -- Gold [('Thermal Grizzly', 'BRAND')]
# Correct: [('LCDOLED', 'BRAND')]
# Correct: [('Staples', 'BRAND')]
# Wrong: Prediction [('Weekender', 'BRAND')]  -- Gold [('', 'BRAND')]
# Correct: [('Zhone', 'BRAND')]
# Correct: [('CaseCrown', 'BRAND')]
# Correct: [('UNIS', 'BRAND')]
# Correct: [('IBM', 'BRAND')]
# Wrong: Prediction [('i-', 'BRAND')]  -- Gold [('i-Visor', 'BRAND')]
# Correct: [('RELPER', 'BRAND')]
# Correct: [('All-inside', 'BRAND')]
# Correct: [('Adesso', 'BRAND')]
# Correct: [('RIOTORO', 'BRAND')]
# Correct: [('RoseArt', 'BRAND')]
# Wrong: Prediction [('IBM 42D0678', 'BRAND')]  -- Gold [('IBM', 'BRAND')]
# Correct: [('Glantop', 'BRAND')]
# Wrong: Prediction []  -- Gold [('360LaptopParts', 'BRAND')]
# Correct: [('Motoraux', 'BRAND')]
# Correct: [('Hipstreet', 'BRAND')]
# Correct: [('YOUNGFLY', 'BRAND')]
# Correct: [('YOUNGFLY', 'BRAND')]
# Wrong: Prediction []  -- Gold [('SEP', 'BRAND')]
# Correct: [('Leathario', 'BRAND')]
# Correct: [('Enover', 'BRAND')]
# Wrong: Prediction [('Targus CityGear', 'BRAND')]  -- Gold [('Targus', 'BRAND')]
# Correct: [('LCDOLED', 'BRAND')]
# Wrong: Prediction []  -- Gold [('Star Wars Backpack School Travel Bag Pilot Rebel Alliance Icon Logo', 'BRAND')]
# Correct: [('Mushkin', 'BRAND')]
# Correct: [('E-BOUR', 'BRAND')]
# Correct: [('Ducky', 'BRAND')]
# Correct: [('Ducky', 'BRAND')]
# Correct: [('Nabi', 'BRAND')]
# Correct: [('Staples', 'BRAND')]
# Correct: [('Mosiso', 'BRAND')]
# Correct: [('Nabi', 'BRAND')]
# Correct: [('Mosiso', 'BRAND')]
# Correct: [('Mosiso', 'BRAND')]
# Wrong: Prediction [('Amped', 'BRAND')]  -- Gold [('Amped Wireless', 'BRAND')]
# Correct: [('DOODEEN', 'BRAND')]
# Correct: [('DOODEEN', 'BRAND')]
# Correct: [('Refiring', 'BRAND')]
# Correct: [('Cuisinart', 'BRAND')]
# Correct: [('Anglin', 'BRAND')]
# Correct: [('MagiDeal', 'BRAND')]
# Correct: [('MagiDeal', 'BRAND')]
# Correct: [('MagiDeal', 'BRAND')]
# Wrong: Prediction [('My', 'BRAND')]  -- Gold [('My Best Friend is a Bag', 'BRAND')]
# Correct: [('Ziopp', 'BRAND')]
# Wrong: Prediction [('Felix', 'BRAND')]  -- Gold [('Felix Corps', 'BRAND')]
# Wrong: Prediction [('Hynes', 'BRAND')]  -- Gold [('Hynes Eagle', 'BRAND')]
# Correct: [('CYELEE', 'BRAND')]
# Correct: [('RELPER', 'BRAND')]
# Correct: [('Incipio', 'BRAND')]
# Correct: [('ASTRO', 'BRAND')]
# Correct: [('Joby', 'BRAND')]
# Correct: [('ESYU', 'BRAND')]
# Correct: [('KINGSLONG', 'BRAND')]
# Correct: [('KINGSLONG', 'BRAND')]
# Correct: [('MagiDeal', 'BRAND')]
# Accuracy 0.75
